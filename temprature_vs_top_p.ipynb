# %%
from openai import OpenAI
from dotenv import load_dotenv
import tiktoken

load_dotenv()
client = OpenAI()

# %%
def compare_sampling(prompt: str):
    configs = [
        {"temperature": 0.0, "top_p": 0.9},
        {"temperature": 0.7, "top_p": 0.8},
        {"temperature": 1.5, "top_p": None},
        {"temperature": 1.5, "top_p": None},
    ]

    messages = [{"role": "user", "content": prompt}]

    for config in configs:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            temperature=config["temperature"],
        )
        res = ""
        if config["top_p"]:
            res += client.chat.completions.create(
                model="gpt-4o-mini",
                messages=messages,
                top_p=config["top_p"],
            ).choices[0].message.content
        print(f"Config: {config}")
        print(f"Response: {response.choices[0].message.content} \n {res}\n\n")

# %%
compare_sampling("Name one advantage of using Redis for caching. Be brief.")
# Out:
# Config: {'temperature': 0.0, 'top_p': 0.9}
# Response: One advantage of using Redis for caching is its high performance, allowing for fast data retrieval due to its in-memory data storage.
#  One advantage of using Redis for caching is its high performance, enabling fast read and write operations due to its in-memory data storage.
#
#
# Config: {'temperature': 0.7, 'top_p': 0.8}
# Response: One advantage of using Redis for caching is its high performance, as it provides extremely low latency data access due to its in-memory data storage model.
#  One advantage of using Redis for caching is its high performance, allowing for extremely fast data retrieval due to its in-memory data storage.
#
#
# Config: {'temperature': 1.5, 'top_p': None}
# Response: One advantage of using Redis for caching is its ability to deliver high-speed performance with low latency due to in-memory data storage.
#
#
#
# Config: {'temperature': 1.5, 'top_p': None}
# Response: One advantage of using Redis for caching is its high performance, allowing for fast data retrieval due to its in-memory storage capabilities, which significantly reduces latencies compared to database queries.
